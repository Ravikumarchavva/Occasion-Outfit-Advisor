# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
from PIL import Image

# %%
image = Image.open(r'D:\github\Occasion-Outfit-Advisor\img\Zippered_Shawl_Collar_Blazer\img_00000012.jpg')
plt.imshow(image)
